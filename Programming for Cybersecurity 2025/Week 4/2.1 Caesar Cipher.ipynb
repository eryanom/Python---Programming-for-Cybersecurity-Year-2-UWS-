# %%
# Erya Anom

alphabet = 'abcdefghijklmnopqrstuvwxyz'


def encrypt(plaintext, k):
    ciphertext = ''
    print("\n--- Encryption Process ---")
    for char in plaintext.lower():
        if char in alphabet:
            old_index = alphabet.index(char)
            new_index = (old_index + k) % 26
            new_char = alphabet[new_index]
            print(f"'{char}' -> index {old_index} -> shifted {k} -> new index {new_index} -> '{new_char}'")
            ciphertext += new_char
        else:
            # Non-alphabet characters remain unchanged
            print(f"'{char}' (non-letter) remains unchanged")
            ciphertext += char
    return ciphertext


# Interactive input loop
while True:
    plaintext = input("\nEnter your plaintext (or type 'stop' to quit): ").strip()
    if plaintext.lower() == "stop":
        print("Goodbye! ")
        break

    try:
        shift = int(input("Enter shift value (e.g., 1, 2, 3...): "))
    except ValueError:
        print("Please enter a valid number for the shift.")
        continue

    ciphertext = encrypt(plaintext, shift)
    print("\nPlaintext:", plaintext)
    print("Ciphertext:", ciphertext)
    print("-" * 40)
# Out:
# --- Encryption Process ---
# 'e' -> index 4 -> shifted 1 -> new index 5 -> 'f'
# 'r' -> index 17 -> shifted 1 -> new index 18 -> 's'
# 'y' -> index 24 -> shifted 1 -> new index 25 -> 'z'
# 'a' -> index 0 -> shifted 1 -> new index 1 -> 'b'
#
# Plaintext: erya
# Ciphertext: fszb
# ----------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 25
#      23 # Interactive input loop
#      24 while True:
# ---> 25     plaintext = input("\nEnter your plaintext (or type 'stop' to quit): ").strip()
#      26     if plaintext.lower() == "stop":
#      27         print("Goodbye! ")
#
# File ~/Documents/Programming for Cybersecurity 2025/.venv/lib/python3.9/site-packages/ipykernel/kernelbase.py:1275, in Kernel.raw_input(self, prompt)
#    1273     msg = "raw_input was called, but this frontend does not support input requests."
#    1274     raise StdinNotImplementedError(msg)
# -> 1275 return self._input_request(
#    1276     str(prompt),
#    1277     self._parent_ident["shell"],
#    1278     self.get_parent("shell"),
#    1279     password=False,
#    1280 )
#
# File ~/Documents/Programming for Cybersecurity 2025/.venv/lib/python3.9/site-packages/ipykernel/kernelbase.py:1320, in Kernel._input_request(self, prompt, ident, parent, password)
#    1317 except KeyboardInterrupt:
#    1318     # re-raise KeyboardInterrupt, to truncate traceback
#    1319     msg = "Interrupted by user"
# -> 1320     raise KeyboardInterrupt(msg) from None
#    1321 except Exception:
#    1322     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
